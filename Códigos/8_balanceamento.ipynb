# %%
import pandas as pd

# %%
base = pd.read_csv('../Bases/Criados/6.1_base_final.csv')

# %% [markdown]
# ## Eliminação de atributos classificadores e não relevantes

# %%
#Classificadores
# base = base.drop(columns=['H001'])
# base = base.drop(columns=['H002'])
# base = base.drop(columns=['H003'])
# base = base.drop(columns=['H004'])
# base = base.drop(columns=['C008'])
# base = base.drop(columns=['J001'])
# base = base.drop(columns=['J00101'])

#Não relevantes ?
# base = base.drop(columns=['N012'])
# base = base.drop(columns=['N010'])
# base = base.drop(columns=['N011'])
# base = base.drop(columns=['Exposicao_lixo'])
# base = base.drop(columns=['Exposicao_minerio'])
# base = base.drop(columns=['Exposicao_ruido'])
# base = base.drop(columns=['Avaliacao_plano'])
# base = base.drop(columns=['P06701'])

# %%
base.columns
# Out:
# Index(['Situação_censitária', 'Plano_de_saúde',
#        'Frequência_distúrbios_do_sono', 'Frequência_falta_de_disposição',
#        'Frequência_falta_de_interesse', 'Frequência_sintomas_depressivos',
#        'Frequência_consumo_carne_vermelha', 'Frequência_consumo_suco_caixinha',
#        'Frequência_consumo_frutas', 'Frequência_consumo_refrigerante',
#        'Consumo_de_sal', 'Frequência_consumo_de_televisão', 'Hipertensão',
#        'Diabetes', 'Colesterol_alto', 'Doença_cardíaca',
#        'Quantidade_de_trabalhos', 'Jornada_de_Trabalho', 'Exposição_poluentes',
#        'Início_tabagismo', 'Tempo_parou_de_fumar', 'Doença_mental',
#        'Consumo_de_álcool', 'Faixa_IMC'],
#       dtype='object')

# %%
base
# Out:
#        Situação_censitária  Plano_de_saúde  Frequência_distúrbios_do_sono  \
# 0                        1             2.0                            1.0
# 1                        1             1.0                            1.0
# 2                        1             1.0                            1.0
# 3                        1             2.0                            1.0
# 4                        1             2.0                            2.0
# ...                    ...             ...                            ...
# 20494                    2             2.0                            4.0
# 20495                    2             2.0                            2.0
# 20496                    2             2.0                            1.0
# 20497                    2             2.0                            2.0
# 20498                    2             1.0                            1.0
#
#        Frequência_falta_de_disposição  Frequência_falta_de_interesse  \
# 0                                 1.0                            1.0
# 1                                 1.0                            1.0
# 2                                 1.0                            1.0
# 3                                 1.0                            2.0
# 4                                 2.0                            2.0
# ...                               ...                            ...
# 20494                             3.0                            3.0
# 20495                             3.0                            3.0
# 20496                             2.0                            3.0
# 20497                             1.0                            1.0
# 20498                             1.0                            2.0
#
#        Frequência_sintomas_depressivos  Frequência_consumo_carne_vermelha  \
# 0                                  1.0                                  2
# 1                                  2.0                                  3
# 2                                  1.0                                  2
# 3                                  1.0                                  3
# 4                                  2.0                                  2
# ...                                ...                                ...
# 20494                              4.0                                  3
# 20495                              3.0                                  2
# 20496                              2.0                                  2
# 20497                              1.0                                  4
# 20498                              2.0                                  2
#
#        Frequência_consumo_suco_caixinha  Frequência_consumo_frutas  \
# 0                                     1                          3
# 1                                     1                          2
# 2                                     1                          4
# 3                                     1                          3
# 4                                     1                          4
# ...                                 ...                        ...
# 20494                                 1                          4
# 20495                                 2                          2
# 20496                                 1                          2
# 20497                                 1                          2
# 20498                                 1                          2
#
#        Frequência_consumo_refrigerante  ...  Colesterol_alto  Doença_cardíaca  \
# 0                                    2  ...              1.0              2.0
# 1                                    3  ...              1.0              2.0
# 2                                    1  ...              2.0              2.0
# 3                                    1  ...              2.0              2.0
# 4                                    1  ...              2.0              2.0
# ...                                ...  ...              ...              ...
# 20494                                1  ...              2.0              2.0
# 20495                                2  ...              2.0              2.0
# 20496                                2  ...              2.0              2.0
# 20497                                1  ...              2.0              2.0
# 20498                                3  ...              2.0              2.0
#
#        Quantidade_de_trabalhos  Jornada_de_Trabalho  Exposição_poluentes  \
# 0                            1                    1                    2
# 1                            1                    1                    2
# 2                            1                    1                    2
# 3                            0                    0                    2
# 4                            1                    1                    2
# ...                        ...                  ...                  ...
# 20494                        1                    2                    2
# 20495                        1                    2                    1
# 20496                        1                    1                    1
# 20497                        1                    1                    1
# 20498                        1                    1                    2
#
#        Início_tabagismo  Tempo_parou_de_fumar  Doença_mental  \
# 0                     0                     0              2
# 1                     0                     3              2
# 2                     1                     3              2
# 3                     0                     0              2
# 4                     0                     0              2
# ...                 ...                   ...            ...
# 20494                 0                     0              1
# 20495                 0                     0              2
# 20496                 2                     1              2
# 20497                 3                     1              2
# 20498                 0                     0              1
#
#        Consumo_de_álcool  Faixa_IMC
# 0                      0          3
# 1                      3          3
# 2                      2          2
# 3                      0          2
# 4                      0          3
# ...                  ...        ...
# 20494                  2          1
# 20495                  0          1
# 20496                  1          1
# 20497                  3          2
# 20498                  0          3
#
# [20499 rows x 24 columns]

# %% [markdown]
# ## Separação dos valores de treino e teste

# %%
X_prev = base.drop(columns=['Doença_cardíaca'])
y_classe = base['Doença_cardíaca']

# %%
from sklearn.model_selection import train_test_split

# %%
X_prev
# Out:
#        Situação_censitária  Plano_de_saúde  Frequência_distúrbios_do_sono  \
# 0                        1             2.0                            1.0
# 1                        1             1.0                            1.0
# 2                        1             1.0                            1.0
# 3                        1             2.0                            1.0
# 4                        1             2.0                            2.0
# ...                    ...             ...                            ...
# 20494                    2             2.0                            4.0
# 20495                    2             2.0                            2.0
# 20496                    2             2.0                            1.0
# 20497                    2             2.0                            2.0
# 20498                    2             1.0                            1.0
#
#        Frequência_falta_de_disposição  Frequência_falta_de_interesse  \
# 0                                 1.0                            1.0
# 1                                 1.0                            1.0
# 2                                 1.0                            1.0
# 3                                 1.0                            2.0
# 4                                 2.0                            2.0
# ...                               ...                            ...
# 20494                             3.0                            3.0
# 20495                             3.0                            3.0
# 20496                             2.0                            3.0
# 20497                             1.0                            1.0
# 20498                             1.0                            2.0
#
#        Frequência_sintomas_depressivos  Frequência_consumo_carne_vermelha  \
# 0                                  1.0                                  2
# 1                                  2.0                                  3
# 2                                  1.0                                  2
# 3                                  1.0                                  3
# 4                                  2.0                                  2
# ...                                ...                                ...
# 20494                              4.0                                  3
# 20495                              3.0                                  2
# 20496                              2.0                                  2
# 20497                              1.0                                  4
# 20498                              2.0                                  2
#
#        Frequência_consumo_suco_caixinha  Frequência_consumo_frutas  \
# 0                                     1                          3
# 1                                     1                          2
# 2                                     1                          4
# 3                                     1                          3
# 4                                     1                          4
# ...                                 ...                        ...
# 20494                                 1                          4
# 20495                                 2                          2
# 20496                                 1                          2
# 20497                                 1                          2
# 20498                                 1                          2
#
#        Frequência_consumo_refrigerante  ...  Diabetes  Colesterol_alto  \
# 0                                    2  ...       2.0              1.0
# 1                                    3  ...       2.0              1.0
# 2                                    1  ...       2.0              2.0
# 3                                    1  ...       2.0              2.0
# 4                                    1  ...       2.0              2.0
# ...                                ...  ...       ...              ...
# 20494                                1  ...       2.0              2.0
# 20495                                2  ...       2.0              2.0
# 20496                                2  ...       2.0              2.0
# 20497                                1  ...       2.0              2.0
# 20498                                3  ...       2.0              2.0
#
#        Quantidade_de_trabalhos  Jornada_de_Trabalho  Exposição_poluentes  \
# 0                            1                    1                    2
# 1                            1                    1                    2
# 2                            1                    1                    2
# 3                            0                    0                    2
# 4                            1                    1                    2
# ...                        ...                  ...                  ...
# 20494                        1                    2                    2
# 20495                        1                    2                    1
# 20496                        1                    1                    1
# 20497                        1                    1                    1
# 20498                        1                    1                    2
#
#        Início_tabagismo  Tempo_parou_de_fumar  Doença_mental  \
# 0                     0                     0              2
# 1                     0                     3              2
# 2                     1                     3              2
# 3                     0                     0              2
# 4                     0                     0              2
# ...                 ...                   ...            ...
# 20494                 0                     0              1
# 20495                 0                     0              2
# 20496                 2                     1              2
# 20497                 3                     1              2
# 20498                 0                     0              1
#
#        Consumo_de_álcool  Faixa_IMC
# 0                      0          3
# 1                      3          3
# 2                      2          2
# 3                      0          2
# 4                      0          3
# ...                  ...        ...
# 20494                  2          1
# 20495                  0          1
# 20496                  1          1
# 20497                  3          2
# 20498                  0          3
#
# [20499 rows x 23 columns]

# %%
y_classe
# Out:
# 0        2.0
# 1        2.0
# 2        2.0
# 3        2.0
# 4        2.0
#         ...
# 20494    2.0
# 20495    2.0
# 20496    2.0
# 20497    2.0
# 20498    2.0
# Name: Doença_cardíaca, Length: 20499, dtype: float64

# %%
y_classe.shape
# Out:
# (20499,)

# %%
X_treino, X_teste, y_treino, y_teste = train_test_split(X_prev, y_classe, test_size=0.3, random_state=42)

# %%
X_treino.shape
# Out:
# (14349, 23)

# %%
X_teste.shape
# Out:
# (6150, 23)

# %%
X_teste
# Out:
#        Situação_censitária  Plano_de_saúde  Frequência_distúrbios_do_sono  \
# 16109                    1             2.0                            1.0
# 2457                     1             2.0                            1.0
# 1077                     1             2.0                            1.0
# 11386                    1             2.0                            4.0
# 15535                    1             1.0                            1.0
# ...                    ...             ...                            ...
# 7826                     2             2.0                            1.0
# 2074                     2             2.0                            4.0
# 8136                     2             2.0                            1.0
# 12777                    2             2.0                            2.0
# 7071                     1             2.0                            2.0
#
#        Frequência_falta_de_disposição  Frequência_falta_de_interesse  \
# 16109                             1.0                            1.0
# 2457                              1.0                            1.0
# 1077                              1.0                            2.0
# 11386                             2.0                            2.0
# 15535                             1.0                            1.0
# ...                               ...                            ...
# 7826                              1.0                            1.0
# 2074                              2.0                            2.0
# 8136                              1.0                            1.0
# 12777                             3.0                            3.0
# 7071                              1.0                            1.0
#
#        Frequência_sintomas_depressivos  Frequência_consumo_carne_vermelha  \
# 16109                              1.0                                  3
# 2457                               2.0                                  2
# 1077                               2.0                                  4
# 11386                              3.0                                  2
# 15535                              1.0                                  3
# ...                                ...                                ...
# 7826                               1.0                                  2
# 2074                               1.0                                  1
# 8136                               1.0                                  2
# 12777                              2.0                                  2
# 7071                               1.0                                  2
#
#        Frequência_consumo_suco_caixinha  Frequência_consumo_frutas  \
# 16109                                 1                          1
# 2457                                  1                          4
# 1077                                  1                          4
# 11386                                 1                          4
# 15535                                 1                          4
# ...                                 ...                        ...
# 7826                                  3                          2
# 2074                                  1                          4
# 8136                                  2                          2
# 12777                                 1                          2
# 7071                                  1                          4
#
#        Frequência_consumo_refrigerante  ...  Diabetes  Colesterol_alto  \
# 16109                                1  ...       2.0              2.0
# 2457                                 1  ...       2.0              2.0
# 1077                                 1  ...       2.0              2.0
# 11386                                1  ...       2.0              1.0
# 15535                                1  ...       2.0              1.0
# ...                                ...  ...       ...              ...
# 7826                                 2  ...       2.0              2.0
# 2074                                 1  ...       1.0              1.0
# 8136                                 1  ...       2.0              2.0
# 12777                                1  ...       2.0              2.0
# 7071                                 1  ...       2.0              2.0
#
#        Quantidade_de_trabalhos  Jornada_de_Trabalho  Exposição_poluentes  \
# 16109                        1                    2                    1
# 2457                         1                    1                    1
# 1077                         0                    0                    2
# 11386                        0                    0                    2
# 15535                        0                    0                    2
# ...                        ...                  ...                  ...
# 7826                         0                    0                    2
# 2074                         0                    0                    2
# 8136                         1                    1                    2
# 12777                        1                    1                    2
# 7071                         1                    1                    1
#
#        Início_tabagismo  Tempo_parou_de_fumar  Doença_mental  \
# 16109                 0                     0              2
# 2457                  0                     0              2
# 1077                  0                     3              2
# 11386                 1                     2              2
# 15535                 1                     3              2
# ...                 ...                   ...            ...
# 7826                  1                     1              2
# 2074                  1                     3              2
# 8136                  0                     0              2
# 12777                 2                     3              2
# 7071                  0                     0              2
#
#        Consumo_de_álcool  Faixa_IMC
# 16109                  2          3
# 2457                   1          1
# 1077                   0          3
# 11386                  0          1
# 15535                  1          2
# ...                  ...        ...
# 7826                   0          1
# 2074                   0          2
# 8136                   0          2
# 12777                  0          1
# 7071                   0          3
#
# [6150 rows x 23 columns]

# %%
y_treino
# Out:
# 9315     2.0
# 3290     2.0
# 20119    2.0
# 914      2.0
# 7924     2.0
#         ...
# 11284    2.0
# 11964    2.0
# 5390     2.0
# 860      2.0
# 15795    2.0
# Name: Doença_cardíaca, Length: 14349, dtype: float64

# %%
y_teste
# Out:
# 16109    2.0
# 2457     2.0
# 1077     1.0
# 11386    2.0
# 15535    2.0
#         ...
# 7826     2.0
# 2074     2.0
# 8136     2.0
# 12777    2.0
# 7071     2.0
# Name: Doença_cardíaca, Length: 6150, dtype: float64

# %%
y_treino.value_counts()
# Out:
# Doença_cardíaca
# 2.0    13555
# 1.0      794
# Name: count, dtype: int64

# %%
y_teste.value_counts()
# Out:
# Doença_cardíaca
# 2.0    5790
# 1.0     360
# Name: count, dtype: int64

# %%
import numpy as np

# %%
np.savez('../Bases/Criados/Treino_Teste/treino_teste.npz', X_treino=X_treino, X_teste=X_teste, y_treino=y_treino, y_teste=y_teste, feature_names=X_treino.columns)

# %%
df_treino_original = pd.concat([X_treino.reset_index(drop=True), y_treino.reset_index(drop=True)], axis=1)
df_teste_original = pd.concat([X_teste.reset_index(drop=True), y_teste.reset_index(drop=True)], axis=1)

df_treino_original.to_csv("../Bases/Criados/Treino_Teste/treino.csv", index=False)
df_teste_original.to_csv("../Bases/Criados/Treino_Teste/teste.csv", index=False)

# %% [markdown]
# ## Correlação

# %%
import seaborn as sns

# %%
base.corr()
# Out:
#                                    Situação_censitária  Plano_de_saúde  \
# Situação_censitária                           1.000000        0.227575
# Plano_de_saúde                                0.227575        1.000000
# Frequência_distúrbios_do_sono                -0.060089       -0.005745
# Frequência_falta_de_disposição               -0.076930        0.005908
# Frequência_falta_de_interesse                -0.073351        0.017881
# Frequência_sintomas_depressivos              -0.065404        0.043147
# Frequência_consumo_carne_vermelha             0.017635       -0.056007
# Frequência_consumo_suco_caixinha              0.044969        0.070016
# Frequência_consumo_frutas                    -0.175058       -0.201072
# Frequência_consumo_refrigerante              -0.102506       -0.021089
# Consumo_de_sal                                0.027640        0.032373
# Frequência_consumo_de_televisão              -0.012366        0.030470
# Hipertensão                                   0.039958        0.012167
# Diabetes                                      0.046195        0.013820
# Colesterol_alto                               0.054315        0.068347
# Doença_cardíaca                               0.035642        0.029907
# Quantidade_de_trabalhos                      -0.091882       -0.099133
# Jornada_de_Trabalho                          -0.095440       -0.076458
# Exposição_poluentes                           0.061679        0.023607
# Início_tabagismo                              0.050517        0.079712
# Tempo_parou_de_fumar                          0.046116        0.064028
# Doença_mental                                 0.071837        0.062698
# Consumo_de_álcool                            -0.066091       -0.067723
# Faixa_IMC                                    -0.093430       -0.048879
#
#                                    Frequência_distúrbios_do_sono  \
# Situação_censitária                                    -0.060089
# Plano_de_saúde                                         -0.005745
# Frequência_distúrbios_do_sono                           1.000000
# Frequência_falta_de_disposição                          0.461881
# Frequência_falta_de_interesse                           0.423789
# Frequência_sintomas_depressivos                         0.418532
# Frequência_consumo_carne_vermelha                      -0.077827
# Frequência_consumo_suco_caixinha                       -0.009385
# Frequência_consumo_frutas                              -0.008173
# Frequência_consumo_refrigerante                        -0.038576
# Consumo_de_sal                                          0.004584
# Frequência_consumo_de_televisão                         0.082494
# Hipertensão                                            -0.127344
# Diabetes                                               -0.079781
# Colesterol_alto                                        -0.155649
# Doença_cardíaca                                        -0.106726
# Quantidade_de_trabalhos                                -0.101837
# Jornada_de_Trabalho                                    -0.099335
# Exposição_poluentes                                     0.026005
# Início_tabagismo                                        0.048313
# Tempo_parou_de_fumar                                    0.052314
# Doença_mental                                          -0.305004
# Consumo_de_álcool                                      -0.031808
# Faixa_IMC                                               0.012364
#
#                                    Frequência_falta_de_disposição  \
# Situação_censitária                                     -0.076930
# Plano_de_saúde                                           0.005908
# Frequência_distúrbios_do_sono                            0.461881
# Frequência_falta_de_disposição                           1.000000
# Frequência_falta_de_interesse                            0.583314
# Frequência_sintomas_depressivos                          0.474738
# Frequência_consumo_carne_vermelha                       -0.064577
# Frequência_consumo_suco_caixinha                         0.012538
# Frequência_consumo_frutas                               -0.011229
# Frequência_consumo_refrigerante                         -0.017752
# Consumo_de_sal                                          -0.003141
# Frequência_consumo_de_televisão                          0.039466
# Hipertensão                                             -0.116185
# Diabetes                                                -0.079702
# Colesterol_alto                                         -0.146935
# Doença_cardíaca                                         -0.108496
# Quantidade_de_trabalhos                                 -0.043538
# Jornada_de_Trabalho                                     -0.035476
# Exposição_poluentes                                     -0.025062
# Início_tabagismo                                         0.038951
# Tempo_parou_de_fumar                                     0.041015
# Doença_mental                                           -0.258208
# Consumo_de_álcool                                       -0.042752
# Faixa_IMC                                                0.027660
#
#                                    Frequência_falta_de_interesse  \
# Situação_censitária                                    -0.073351
# Plano_de_saúde                                          0.017881
# Frequência_distúrbios_do_sono                           0.423789
# Frequência_falta_de_disposição                          0.583314
# Frequência_falta_de_interesse                           1.000000
# Frequência_sintomas_depressivos                         0.558567
# Frequência_consumo_carne_vermelha                      -0.062222
# Frequência_consumo_suco_caixinha                        0.010708
# Frequência_consumo_frutas                              -0.027799
# Frequência_consumo_refrigerante                        -0.003038
# Consumo_de_sal                                          0.005975
# Frequência_consumo_de_televisão                         0.074920
# Hipertensão                                            -0.097134
# Diabetes                                               -0.078621
# Colesterol_alto                                        -0.133344
# Doença_cardíaca                                        -0.106462
# Quantidade_de_trabalhos                                -0.069973
# Jornada_de_Trabalho                                    -0.067643
# Exposição_poluentes                                     0.003269
# Início_tabagismo                                        0.046730
# Tempo_parou_de_fumar                                    0.047000
# Doença_mental                                          -0.287325
# Consumo_de_álcool                                      -0.039856
# Faixa_IMC                                               0.042578
#
#                                    Frequência_sintomas_depressivos  \
# Situação_censitária                                      -0.065404
# Plano_de_saúde                                            0.043147
# Frequência_distúrbios_do_sono                             0.418532
# Frequência_falta_de_disposição                            0.474738
# Frequência_falta_de_interesse                             0.558567
# Frequência_sintomas_depressivos                           1.000000
# Frequência_consumo_carne_vermelha                        -0.079069
# Frequência_consumo_suco_caixinha                          0.016578
# Frequência_consumo_frutas                                -0.027476
# Frequência_consumo_refrigerante                          -0.022686
# Consumo_de_sal                                            0.011412
# Frequência_consumo_de_televisão                           0.072032
# Hipertensão                                              -0.099277
# Diabetes                                                 -0.064403
# Colesterol_alto                                          -0.128100
# Doença_cardíaca                                          -0.103259
# Quantidade_de_trabalhos                                  -0.093250
# Jornada_de_Trabalho                                      -0.088112
# Exposição_poluentes                                       0.027199
# Início_tabagismo                                          0.056623
# Tempo_parou_de_fumar                                      0.048931
# Doença_mental                                            -0.331775
# Consumo_de_álcool                                        -0.037650
# Faixa_IMC                                                 0.021859
#
#                                    Frequência_consumo_carne_vermelha  \
# Situação_censitária                                         0.017635
# Plano_de_saúde                                             -0.056007
# Frequência_distúrbios_do_sono                              -0.077827
# Frequência_falta_de_disposição                             -0.064577
# Frequência_falta_de_interesse                              -0.062222
# Frequência_sintomas_depressivos                            -0.079069
# Frequência_consumo_carne_vermelha                           1.000000
# Frequência_consumo_suco_caixinha                            0.084751
# Frequência_consumo_frutas                                  -0.025777
# Frequência_consumo_refrigerante                             0.174702
# Consumo_de_sal                                             -0.109716
# Frequência_consumo_de_televisão                            -0.030067
# Hipertensão                                                 0.039020
# Diabetes                                                    0.045232
# Colesterol_alto                                             0.056131
# Doença_cardíaca                                             0.024501
# Quantidade_de_trabalhos                                     0.096510
# Jornada_de_Trabalho                                         0.102726
# Exposição_poluentes                                        -0.076370
# Início_tabagismo                                            0.021046
# Tempo_parou_de_fumar                                       -0.005388
# Doença_mental                                               0.041308
# Consumo_de_álcool                                           0.107253
# Faixa_IMC                                                   0.021302
#
#                                    Frequência_consumo_suco_caixinha  \
# Situação_censitária                                        0.044969
# Plano_de_saúde                                             0.070016
# Frequência_distúrbios_do_sono                             -0.009385
# Frequência_falta_de_disposição                             0.012538
# Frequência_falta_de_interesse                              0.010708
# Frequência_sintomas_depressivos                            0.016578
# Frequência_consumo_carne_vermelha                          0.084751
# Frequência_consumo_suco_caixinha                           1.000000
# Frequência_consumo_frutas                                 -0.116967
# Frequência_consumo_refrigerante                            0.187875
# Consumo_de_sal                                            -0.064794
# Frequência_consumo_de_televisão                            0.033307
# Hipertensão                                                0.025063
# Diabetes                                                   0.053692
# Colesterol_alto                                            0.050060
# Doença_cardíaca                                            0.017997
# Quantidade_de_trabalhos                                    0.003737
# Jornada_de_Trabalho                                        0.013871
# Exposição_poluentes                                       -0.052662
# Início_tabagismo                                           0.045229
# Tempo_parou_de_fumar                                       0.014718
# Doença_mental                                              0.015010
# Consumo_de_álcool                                          0.039628
# Faixa_IMC                                                 -0.014365
#
#                                    Frequência_consumo_frutas  \
# Situação_censitária                                -0.175058
# Plano_de_saúde                                     -0.201072
# Frequência_distúrbios_do_sono                      -0.008173
# Frequência_falta_de_disposição                     -0.011229
# Frequência_falta_de_interesse                      -0.027799
# Frequência_sintomas_depressivos                    -0.027476
# Frequência_consumo_carne_vermelha                  -0.025777
# Frequência_consumo_suco_caixinha                   -0.116967
# Frequência_consumo_frutas                           1.000000
# Frequência_consumo_refrigerante                    -0.090983
# Consumo_de_sal                                      0.065423
# Frequência_consumo_de_televisão                    -0.034617
# Hipertensão                                        -0.042560
# Diabetes                                           -0.063601
# Colesterol_alto                                    -0.055715
# Doença_cardíaca                                    -0.029043
# Quantidade_de_trabalhos                             0.016764
# Jornada_de_Trabalho                                 0.008931
# Exposição_poluentes                                 0.011042
# Início_tabagismo                                   -0.074432
# Tempo_parou_de_fumar                               -0.034423
# Doença_mental                                      -0.042898
# Consumo_de_álcool                                  -0.059199
# Faixa_IMC                                           0.026339
#
#                                    Frequência_consumo_refrigerante  ...  \
# Situação_censitária                                      -0.102506  ...
# Plano_de_saúde                                           -0.021089  ...
# Frequência_distúrbios_do_sono                            -0.038576  ...
# Frequência_falta_de_disposição                           -0.017752  ...
# Frequência_falta_de_interesse                            -0.003038  ...
# Frequência_sintomas_depressivos                          -0.022686  ...
# Frequência_consumo_carne_vermelha                         0.174702  ...
# Frequência_consumo_suco_caixinha                          0.187875  ...
# Frequência_consumo_frutas                                -0.090983  ...
# Frequência_consumo_refrigerante                           1.000000  ...
# Consumo_de_sal                                           -0.144422  ...
# Frequência_consumo_de_televisão                          -0.001253  ...
# Hipertensão                                               0.060479  ...
# Diabetes                                                  0.083477  ...
# Colesterol_alto                                           0.069281  ...
# Doença_cardíaca                                           0.044654  ...
# Quantidade_de_trabalhos                                   0.126955  ...
# Jornada_de_Trabalho                                       0.138601  ...
# Exposição_poluentes                                      -0.103617  ...
# Início_tabagismo                                          0.013724  ...
# Tempo_parou_de_fumar                                     -0.019981  ...
# Doença_mental                                             0.023440  ...
# Consumo_de_álcool                                         0.134747  ...
# Faixa_IMC                                                 0.041912  ...
#
#                                    Colesterol_alto  Doença_cardíaca  \
# Situação_censitária                       0.054315         0.035642
# Plano_de_saúde                            0.068347         0.029907
# Frequência_distúrbios_do_sono            -0.155649        -0.106726
# Frequência_falta_de_disposição           -0.146935        -0.108496
# Frequência_falta_de_interesse            -0.133344        -0.106462
# Frequência_sintomas_depressivos          -0.128100        -0.103259
# Frequência_consumo_carne_vermelha         0.056131         0.024501
# Frequência_consumo_suco_caixinha          0.050060         0.017997
# Frequência_consumo_frutas                -0.055715        -0.029043
# Frequência_consumo_refrigerante           0.069281         0.044654
# Consumo_de_sal                           -0.048972        -0.059817
# Frequência_consumo_de_televisão          -0.022955        -0.038838
# Hipertensão                               0.228758         0.160921
# Diabetes                                  0.194510         0.094695
# Colesterol_alto                           1.000000         0.146536
# Doença_cardíaca                           0.146536         1.000000
# Quantidade_de_trabalhos                   0.082491         0.072814
# Jornada_de_Trabalho                       0.084490         0.070394
# Exposição_poluentes                      -0.045113        -0.040778
# Início_tabagismo                         -0.025614        -0.032345
# Tempo_parou_de_fumar                     -0.062863        -0.053420
# Doença_mental                             0.136410         0.105285
# Consumo_de_álcool                         0.043396         0.037679
# Faixa_IMC                                -0.094568        -0.026256
#
#                                    Quantidade_de_trabalhos  \
# Situação_censitária                              -0.091882
# Plano_de_saúde                                   -0.099133
# Frequência_distúrbios_do_sono                    -0.101837
# Frequência_falta_de_disposição                   -0.043538
# Frequência_falta_de_interesse                    -0.069973
# Frequência_sintomas_depressivos                  -0.093250
# Frequência_consumo_carne_vermelha                 0.096510
# Frequência_consumo_suco_caixinha                  0.003737
# Frequência_consumo_frutas                         0.016764
# Frequência_consumo_refrigerante                   0.126955
# Consumo_de_sal                                   -0.101793
# Frequência_consumo_de_televisão                  -0.087486
# Hipertensão                                       0.152323
# Diabetes                                          0.109222
# Colesterol_alto                                   0.082491
# Doença_cardíaca                                   0.072814
# Quantidade_de_trabalhos                           1.000000
# Jornada_de_Trabalho                               0.865375
# Exposição_poluentes                              -0.392351
# Início_tabagismo                                 -0.053680
# Tempo_parou_de_fumar                             -0.070101
# Doença_mental                                     0.062838
# Consumo_de_álcool                                 0.176970
# Faixa_IMC                                         0.010978
#
#                                    Jornada_de_Trabalho  Exposição_poluentes  \
# Situação_censitária                          -0.095440             0.061679
# Plano_de_saúde                               -0.076458             0.023607
# Frequência_distúrbios_do_sono                -0.099335             0.026005
# Frequência_falta_de_disposição               -0.035476            -0.025062
# Frequência_falta_de_interesse                -0.067643             0.003269
# Frequência_sintomas_depressivos              -0.088112             0.027199
# Frequência_consumo_carne_vermelha             0.102726            -0.076370
# Frequência_consumo_suco_caixinha              0.013871            -0.052662
# Frequência_consumo_frutas                     0.008931             0.011042
# Frequência_consumo_refrigerante               0.138601            -0.103617
# Consumo_de_sal                               -0.102513             0.069024
# Frequência_consumo_de_televisão              -0.084687             0.033911
# Hipertensão                                   0.144514            -0.069234
# Diabetes                                      0.103413            -0.052244
# Colesterol_alto                               0.084490            -0.045113
# Doença_cardíaca                               0.070394            -0.040778
# Quantidade_de_trabalhos                       0.865375            -0.392351
# Jornada_de_Trabalho                           1.000000            -0.390290
# Exposição_poluentes                          -0.390290             1.000000
# Início_tabagismo                             -0.044120             0.007415
# Tempo_parou_de_fumar                         -0.060251             0.008929
# Doença_mental                                 0.069915            -0.025281
# Consumo_de_álcool                             0.179585            -0.122294
# Faixa_IMC                                     0.019187            -0.011209
#
#                                    Início_tabagismo  Tempo_parou_de_fumar  \
# Situação_censitária                        0.050517              0.046116
# Plano_de_saúde                             0.079712              0.064028
# Frequência_distúrbios_do_sono              0.048313              0.052314
# Frequência_falta_de_disposição             0.038951              0.041015
# Frequência_falta_de_interesse              0.046730              0.047000
# Frequência_sintomas_depressivos            0.056623              0.048931
# Frequência_consumo_carne_vermelha          0.021046             -0.005388
# Frequência_consumo_suco_caixinha           0.045229              0.014718
# Frequência_consumo_frutas                 -0.074432             -0.034423
# Frequência_consumo_refrigerante            0.013724             -0.019981
# Consumo_de_sal                            -0.000634              0.023545
# Frequência_consumo_de_televisão            0.063126              0.042393
# Hipertensão                               -0.028977             -0.074438
# Diabetes                                  -0.028593             -0.054359
# Colesterol_alto                           -0.025614             -0.062863
# Doença_cardíaca                           -0.032345             -0.053420
# Quantidade_de_trabalhos                   -0.053680             -0.070101
# Jornada_de_Trabalho                       -0.044120             -0.060251
# Exposição_poluentes                        0.007415              0.008929
# Início_tabagismo                           1.000000              0.694036
# Tempo_parou_de_fumar                       0.694036              1.000000
# Doença_mental                             -0.009346             -0.004375
# Consumo_de_álcool                          0.144763              0.100370
# Faixa_IMC                                 -0.039642              0.009247
#
#                                    Doença_mental  Consumo_de_álcool  Faixa_IMC
# Situação_censitária                     0.071837          -0.066091  -0.093430
# Plano_de_saúde                          0.062698          -0.067723  -0.048879
# Frequência_distúrbios_do_sono          -0.305004          -0.031808   0.012364
# Frequência_falta_de_disposição         -0.258208          -0.042752   0.027660
# Frequência_falta_de_interesse          -0.287325          -0.039856   0.042578
# Frequência_sintomas_depressivos        -0.331775          -0.037650   0.021859
# Frequência_consumo_carne_vermelha       0.041308           0.107253   0.021302
# Frequência_consumo_suco_caixinha        0.015010           0.039628  -0.014365
# Frequência_consumo_frutas              -0.042898          -0.059199   0.026339
# Frequência_consumo_refrigerante         0.023440           0.134747   0.041912
# Consumo_de_sal                         -0.015380          -0.115253   0.013185
# Frequência_consumo_de_televisão        -0.046147           0.023012   0.013807
# Hipertensão                             0.091908           0.073898  -0.195772
# Diabetes                                0.028414           0.068768  -0.093456
# Colesterol_alto                         0.136410           0.043396  -0.094568
# Doença_cardíaca                         0.105285           0.037679  -0.026256
# Quantidade_de_trabalhos                 0.062838           0.176970   0.010978
# Jornada_de_Trabalho                     0.069915           0.179585   0.019187
# Exposição_poluentes                    -0.025281          -0.122294  -0.011209
# Início_tabagismo                       -0.009346           0.144763  -0.039642
# Tempo_parou_de_fumar                   -0.004375           0.100370   0.009247
# Doença_mental                           1.000000           0.067572  -0.036091
# Consumo_de_álcool                       0.067572           1.000000   0.017794
# Faixa_IMC                              -0.036091           0.017794   1.000000
#
# [24 rows x 24 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define o tamanho da imagem em HD
plt.figure(figsize=(20, 15))  # (largura, altura) em polegadas

# Gera a matriz de correlação
correlacao = base.corr()

# Cria o heatmap com melhorias
sns.heatmap(correlacao, 
            annot=False,         # Se quiser mostrar os valores, mude para True
            cmap='coolwarm',     # Paleta de cores
            cbar=True,           # Exibe a barra de cores
            xticklabels=True, 
            yticklabels=True)

# Rotaciona os nomes das colunas e linhas para caber melhor
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(rotation=0, fontsize=10)

# Título opcional
plt.title('Matriz de Correlação', fontsize=16)

# Ajusta layout para evitar corte de texto
plt.tight_layout()

# Exibe o gráfico
plt.show()

# %% [markdown]
# ## OverSampling

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_treino, y_treino)

# %%
np.savez('../Bases/Criados/Treino_Teste/over.npz', X_treino=X_resampled, X_teste=X_teste, y_treino=y_resampled, y_teste=y_teste, feature_names=X_treino.columns)

# %%
df_over = pd.concat([pd.DataFrame(X_resampled, columns=X_treino.columns),
                     pd.DataFrame(y_resampled, columns=['Q06306'])], axis=1)
df_over.to_csv("../Bases/Criados/Treino_Teste/over.csv", index=False)

# %% [markdown]
# ## UnderSampling

# %%
from imblearn.under_sampling import TomekLinks
balanceamento_under = TomekLinks(sampling_strategy='auto')
X_under, y_under = balanceamento_under.fit_resample(X_treino, y_treino)

# %%
np.savez('../Bases/Criados/Treino_Teste/under.npz', X_treino=X_under, X_teste=X_teste, y_treino=y_under, y_teste=y_teste, feature_names=X_treino.columns)

# %%
df_under = pd.concat([pd.DataFrame(X_under, columns=X_treino.columns),
                      pd.DataFrame(y_under, columns=['Q06306'])], axis=1)
df_under.to_csv("../Bases/Criados/Treino_Teste/under.csv", index=False)

# %% [markdown]
# ## Random UnderSampling

# %%
from imblearn.under_sampling import RandomUnderSampler
undersample = RandomUnderSampler(random_state=42)
X_resampled, y_resampled = undersample.fit_resample(X_treino, y_treino)

# %%
np.savez('../Bases/Criados/Treino_Teste/random.npz', X_treino=X_resampled, X_teste=X_teste, y_treino=y_resampled, y_teste=y_teste, feature_names=X_treino.columns)

# %%
df_random = pd.concat([pd.DataFrame(X_resampled, columns=X_treino.columns),
                       pd.DataFrame(y_resampled, columns=['Q06306'])], axis=1)
df_random.to_csv("../Bases/Criados/Treino_Teste/random.csv", index=False)

# %% [markdown]
# ## DSTO-GAN

# %%
X_treino = X_treino.astype(np.float32)
y_treino = y_treino.astype(np.float32)

# %%
base
# Out:
#        Situação_censitária  Plano_de_saúde  Frequência_distúrbios_do_sono  \
# 0                        1             2.0                            1.0
# 1                        1             1.0                            1.0
# 2                        1             1.0                            1.0
# 3                        1             2.0                            1.0
# 4                        1             2.0                            2.0
# ...                    ...             ...                            ...
# 20494                    2             2.0                            4.0
# 20495                    2             2.0                            2.0
# 20496                    2             2.0                            1.0
# 20497                    2             2.0                            2.0
# 20498                    2             1.0                            1.0
#
#        Frequência_falta_de_disposição  Frequência_falta_de_interesse  \
# 0                                 1.0                            1.0
# 1                                 1.0                            1.0
# 2                                 1.0                            1.0
# 3                                 1.0                            2.0
# 4                                 2.0                            2.0
# ...                               ...                            ...
# 20494                             3.0                            3.0
# 20495                             3.0                            3.0
# 20496                             2.0                            3.0
# 20497                             1.0                            1.0
# 20498                             1.0                            2.0
#
#        Frequência_sintomas_depressivos  Frequência_consumo_carne_vermelha  \
# 0                                  1.0                                  2
# 1                                  2.0                                  3
# 2                                  1.0                                  2
# 3                                  1.0                                  3
# 4                                  2.0                                  2
# ...                                ...                                ...
# 20494                              4.0                                  3
# 20495                              3.0                                  2
# 20496                              2.0                                  2
# 20497                              1.0                                  4
# 20498                              2.0                                  2
#
#        Frequência_consumo_suco_caixinha  Frequência_consumo_frutas  \
# 0                                     1                          3
# 1                                     1                          2
# 2                                     1                          4
# 3                                     1                          3
# 4                                     1                          4
# ...                                 ...                        ...
# 20494                                 1                          4
# 20495                                 2                          2
# 20496                                 1                          2
# 20497                                 1                          2
# 20498                                 1                          2
#
#        Frequência_consumo_refrigerante  ...  Colesterol_alto  Doença_cardíaca  \
# 0                                    2  ...              1.0              2.0
# 1                                    3  ...              1.0              2.0
# 2                                    1  ...              2.0              2.0
# 3                                    1  ...              2.0              2.0
# 4                                    1  ...              2.0              2.0
# ...                                ...  ...              ...              ...
# 20494                                1  ...              2.0              2.0
# 20495                                2  ...              2.0              2.0
# 20496                                2  ...              2.0              2.0
# 20497                                1  ...              2.0              2.0
# 20498                                3  ...              2.0              2.0
#
#        Quantidade_de_trabalhos  Jornada_de_Trabalho  Exposição_poluentes  \
# 0                            1                    1                    2
# 1                            1                    1                    2
# 2                            1                    1                    2
# 3                            0                    0                    2
# 4                            1                    1                    2
# ...                        ...                  ...                  ...
# 20494                        1                    2                    2
# 20495                        1                    2                    1
# 20496                        1                    1                    1
# 20497                        1                    1                    1
# 20498                        1                    1                    2
#
#        Início_tabagismo  Tempo_parou_de_fumar  Doença_mental  \
# 0                     0                     0              2
# 1                     0                     3              2
# 2                     1                     3              2
# 3                     0                     0              2
# 4                     0                     0              2
# ...                 ...                   ...            ...
# 20494                 0                     0              1
# 20495                 0                     0              2
# 20496                 2                     1              2
# 20497                 3                     1              2
# 20498                 0                     0              1
#
#        Consumo_de_álcool  Faixa_IMC
# 0                      0          3
# 1                      3          3
# 2                      2          2
# 3                      0          2
# 4                      0          3
# ...                  ...        ...
# 20494                  2          1
# 20495                  0          1
# 20496                  1          1
# 20497                  3          2
# 20498                  0          3
#
# [20499 rows x 24 columns]

# %%
from dsto_gan import DSTO_GAN
dsto_gan = DSTO_GAN()
X_resampled, y_resampled = dsto_gan.fit_resample(X_treino.values, y_treino.values)

# %%
np.savez('../Bases/Criados/Treino_Teste/dsto.npz', X_treino=X_resampled, X_teste=X_teste, y_treino=y_resampled, y_teste=y_teste, feature_names=X_treino.columns)

# %%
df_dsto = pd.concat([pd.DataFrame(X_resampled, columns=X_treino.columns),
                     pd.DataFrame(y_resampled, columns=['Q06306'])], axis=1)
df_dsto.to_csv("../Bases/Criados/Treino_Teste/dsto.csv", index=False)
