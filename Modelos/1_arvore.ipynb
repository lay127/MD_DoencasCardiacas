# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier, plot_tree
from skopt import BayesSearchCV
from skopt.space import Integer
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
DC = np.load('../Bases/Criados/Treino_Teste/treino_teste.npz', allow_pickle=True)
X_treino, X_teste, y_treino, y_teste, feature_names = DC['X_treino'], DC['X_teste'], DC['y_treino'], DC['y_teste'], list(DC['feature_names'])

# %%
len(X_treino)
# Out:
# 17022

# %%
DC_over = np.load('../Bases/Criados/Treino_Teste/over.npz', allow_pickle=True)
X_treino_over, X_teste_over, y_treino_over, y_teste_over, feature_names= DC_over['X_treino'], DC_over['X_teste'], DC_over['y_treino'], DC_over['y_teste'], list(DC_over['feature_names'])

# %%
len(X_treino_over)
# Out:
# 31752

# %%
DC_under = np.load('../Bases/Criados/Treino_Teste/under.npz', allow_pickle=True)
X_treino_under, X_teste_under, y_treino_under, y_teste_under, feature_names = DC_under['X_treino'], DC_under['X_teste'], DC_under['y_treino'], DC_under['y_teste'], list(DC_under['feature_names'])

# %%
len(X_treino_under)
# Out:
# 17022

# %%
DC_random_under = np.load('../Bases/Criados/Treino_Teste/random.npz', allow_pickle=True)
X_treino_rd_under, X_teste_rd_under, y_treino_rd_under, y_teste_rd_under, feature_names = DC_random_under['X_treino'], DC_random_under['X_teste'], DC_random_under['y_treino'], DC_random_under['y_teste'], list(DC_random_under['feature_names'])

# %%
len(X_treino_rd_under)
# Out:
# 2292

# %%
#DC_DSTO = np.load('../Bases/Criados/Treino_Teste/dsto.npz', allow_pickle=True)
#X_treino_DSTO, X_teste_DSTO, y_treino_DSTO, y_teste_DSTO, feature_names = DC_DSTO['X_treino'], DC_DSTO['X_teste'], DC_DSTO['y_treino'], DC_DSTO['y_teste'], list(DC_DSTO['feature_names'])

# %%
#len(X_treino_DSTO)

# %% [markdown]
# ## Parametros e funcoes

# %%
param_bayes = {
    'criterion':  ['gini', 'entropy'],
    'max_depth': Integer(1, 50),
    'min_samples_split': Integer(2, 20),
    'min_samples_leaf': Integer(1, 10),
}

# %%
def plot_decision_tree(model, feature_names, class_names, title):
    plt.figure(figsize=(30, 15))
    plot_tree(model, filled=True, feature_names=feature_names, class_names=class_names, rounded=True, fontsize=10)
    plt.title(title)
    plt.show()

# %% [markdown]
# # Modelos

# %% [markdown]
# ### Modelo Padrao

# %%
bayes_search = BayesSearchCV(DecisionTreeClassifier(), param_bayes, n_iter=50, cv=5, scoring='accuracy', random_state=42)
bayes_search.fit(X_treino, y_treino)
print("\nMelhores parâmetros encontrados com BayesSearchCV:")
print(bayes_search.best_params_)
print("Melhor pontuação de validação cruzada: {:.2f}".format(bayes_search.best_score_))
# Out:
# c:\Users\llays\AppData\Local\Programs\Python\Python313\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('gini'), np.int64(49), np.int64(10), np.int64(20)] before, using random point ['entropy', np.int64(19), np.int64(5), np.int64(7)]
#   warnings.warn(
# c:\Users\llays\AppData\Local\Programs\Python\Python313\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('gini'), np.int64(2), np.int64(10), np.int64(2)] before, using random point ['gini', np.int64(23), np.int64(4), np.int64(14)]
#   warnings.warn(
# c:\Users\llays\AppData\Local\Programs\Python\Python313\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('entropy'), np.int64(1), np.int64(10), np.int64(20)] before, using random point ['gini', np.int64(24), np.int64(5), np.int64(13)]
#   warnings.warn(
# c:\Users\llays\AppData\Local\Programs\Python\Python313\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('entropy'), np.int64(1), np.int64(10), np.int64(20)] before, using random point ['entropy', np.int64(43), np.int64(7), np.int64(18)]
#   warnings.warn(
# c:\Users\llays\AppData\Local\Programs\Python\Python313\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('gini'), np.int64(50), np.int64(10), np.int64(2)] before, using random point ['gini', np.int64(10), np.int64(4), np.int64(4)]
#   warnings.warn(
# c:\Users\llays\AppData\Local\Programs\Python\Python313\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('gini'), np.int64(50), np.int64(10), np.int64(20)] before, using random point ['gini', np.int64(19), np.int64(4), np.int64(15)]
#   warnings.warn(
# c:\Users\llays\AppData\Local\Programs\Python\Python313\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('gini'), np.int64(50), np.int64(10), np.int64(20)] before, using random point ['gini', np.int64(24), np.int64(3), np.int64(14)]
#   warnings.warn(
# Melhores parâmetros encontrados com BayesSearchCV:
# OrderedDict({'criterion': 'gini', 'max_depth': 37, 'min_samples_leaf': 9, 'min_samples_split': 8})
# Melhor pontuação de validação cruzada: 1.00

# %%
best_model_bayes = bayes_search.best_estimator_
plot_decision_tree(best_model_bayes, feature_names, ['Tem DC', 'Não tem DC'], "Árvore de Decisão - BayesSearchCV")

# %% [markdown]
# ### Resultados

# %%
previsoes_bayes = best_model_bayes.predict(X_teste)
accuracy_bayes = accuracy_score(y_teste, previsoes_bayes)
print("Acurácia do melhor modelo (BayesSearchCV) no conjunto de teste: {:.2f}".format(accuracy_bayes))
# Out:
# Acurácia do melhor modelo (BayesSearchCV) no conjunto de teste: 1.00

# %%
print(classification_report(y_teste, previsoes_bayes))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       1.00      1.00      1.00       517
#          2.0       1.00      1.00      1.00      6779
#
#     accuracy                           1.00      7296
#    macro avg       1.00      1.00      1.00      7296
# weighted avg       1.00      1.00      1.00      7296

# %%
cfm_matrix = confusion_matrix(y_teste,previsoes_bayes)
sns.heatmap(cfm_matrix, cmap='coolwarm', annot=True, linewidth=1, fmt='d')
plt.show()

# %% [markdown]
# ### OverSampling

# %%
bayes_search.fit(X_treino_over, y_treino_over)
print("\nMelhores parâmetros encontrados com BayesSearchCV:")
print(bayes_search.best_params_)
print("Melhor pontuação de validação cruzada: {:.2f}".format(bayes_search.best_score_))
# Out:
# c:\Users\llays\AppData\Local\Programs\Python\Python313\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('gini'), np.int64(49), np.int64(10), np.int64(20)] before, using random point ['entropy', np.int64(19), np.int64(5), np.int64(7)]
#   warnings.warn(
# c:\Users\llays\AppData\Local\Programs\Python\Python313\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('gini'), np.int64(2), np.int64(10), np.int64(2)] before, using random point ['gini', np.int64(23), np.int64(4), np.int64(14)]
#   warnings.warn(
# c:\Users\llays\AppData\Local\Programs\Python\Python313\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('entropy'), np.int64(1), np.int64(10), np.int64(20)] before, using random point ['gini', np.int64(24), np.int64(5), np.int64(13)]
#   warnings.warn(
# c:\Users\llays\AppData\Local\Programs\Python\Python313\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('entropy'), np.int64(1), np.int64(10), np.int64(20)] before, using random point ['entropy', np.int64(43), np.int64(7), np.int64(18)]
#   warnings.warn(
# c:\Users\llays\AppData\Local\Programs\Python\Python313\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('gini'), np.int64(50), np.int64(10), np.int64(2)] before, using random point ['gini', np.int64(10), np.int64(4), np.int64(4)]
#   warnings.warn(
# c:\Users\llays\AppData\Local\Programs\Python\Python313\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('gini'), np.int64(50), np.int64(10), np.int64(20)] before, using random point ['gini', np.int64(19), np.int64(4), np.int64(15)]
#   warnings.warn(
# c:\Users\llays\AppData\Local\Programs\Python\Python313\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('gini'), np.int64(50), np.int64(10), np.int64(20)] before, using random point ['gini', np.int64(24), np.int64(3), np.int64(14)]
#   warnings.warn(
# Melhores parâmetros encontrados com BayesSearchCV:
# OrderedDict({'criterion': 'gini', 'max_depth': 37, 'min_samples_leaf': 9, 'min_samples_split': 8})
# Melhor pontuação de validação cruzada: 1.00

# %%
best_model_bayes = bayes_search.best_estimator_
plot_decision_tree(best_model_bayes, feature_names, ['Tem DC', 'Não tem DC'], "Árvore de Decisão - BayesSearchCV")

# %%
previsoes_bayes = best_model_bayes.predict(X_teste_over)

# %%
print(classification_report(y_teste_over, previsoes_bayes))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       1.00      1.00      1.00       517
#          2.0       1.00      1.00      1.00      6779
#
#     accuracy                           1.00      7296
#    macro avg       1.00      1.00      1.00      7296
# weighted avg       1.00      1.00      1.00      7296

# %% [markdown]
# ### UnderSampling

# %%
bayes_search.fit(X_treino_under, y_treino_under)
print("\nMelhores parâmetros encontrados com BayesSearchCV:")
print(bayes_search.best_params_)
print("Melhor pontuação de validação cruzada: {:.2f}".format(bayes_search.best_score_))
# Out:
# c:\Users\llays\AppData\Local\Programs\Python\Python313\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('gini'), np.int64(49), np.int64(10), np.int64(20)] before, using random point ['entropy', np.int64(19), np.int64(5), np.int64(7)]
#   warnings.warn(
# c:\Users\llays\AppData\Local\Programs\Python\Python313\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('gini'), np.int64(2), np.int64(10), np.int64(2)] before, using random point ['gini', np.int64(23), np.int64(4), np.int64(14)]
#   warnings.warn(
# c:\Users\llays\AppData\Local\Programs\Python\Python313\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('entropy'), np.int64(1), np.int64(10), np.int64(20)] before, using random point ['gini', np.int64(24), np.int64(5), np.int64(13)]
#   warnings.warn(
# c:\Users\llays\AppData\Local\Programs\Python\Python313\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('entropy'), np.int64(1), np.int64(10), np.int64(20)] before, using random point ['entropy', np.int64(43), np.int64(7), np.int64(18)]
#   warnings.warn(
# c:\Users\llays\AppData\Local\Programs\Python\Python313\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('gini'), np.int64(50), np.int64(10), np.int64(2)] before, using random point ['gini', np.int64(10), np.int64(4), np.int64(4)]
#   warnings.warn(
# c:\Users\llays\AppData\Local\Programs\Python\Python313\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('gini'), np.int64(50), np.int64(10), np.int64(20)] before, using random point ['gini', np.int64(19), np.int64(4), np.int64(15)]
#   warnings.warn(
# c:\Users\llays\AppData\Local\Programs\Python\Python313\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('gini'), np.int64(50), np.int64(10), np.int64(20)] before, using random point ['gini', np.int64(24), np.int64(3), np.int64(14)]
#   warnings.warn(
# Melhores parâmetros encontrados com BayesSearchCV:
# OrderedDict({'criterion': 'gini', 'max_depth': 37, 'min_samples_leaf': 9, 'min_samples_split': 8})
# Melhor pontuação de validação cruzada: 1.00

# %%
best_model_bayes = bayes_search.best_estimator_
plot_decision_tree(best_model_bayes, feature_names, ['Tem DC', 'Não tem DC'], "Árvore de Decisão - BayesSearchCV")

# %%
previsoes_bayes = best_model_bayes.predict(X_teste_under)

# %%
print(classification_report(y_teste_under, previsoes_bayes))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       1.00      1.00      1.00       517
#          2.0       1.00      1.00      1.00      6779
#
#     accuracy                           1.00      7296
#    macro avg       1.00      1.00      1.00      7296
# weighted avg       1.00      1.00      1.00      7296

# %% [markdown]
# ### Random UnderSampling

# %%
bayes_search.fit(X_treino_rd_under, y_treino_rd_under)
print("\nMelhores parâmetros encontrados com BayesSearchCV:")
print(bayes_search.best_params_)
print("Melhor pontuação de validação cruzada: {:.2f}".format(bayes_search.best_score_))
# Out:
# c:\Users\llays\AppData\Local\Programs\Python\Python313\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('gini'), np.int64(49), np.int64(10), np.int64(20)] before, using random point ['entropy', np.int64(19), np.int64(5), np.int64(7)]
#   warnings.warn(
# c:\Users\llays\AppData\Local\Programs\Python\Python313\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('gini'), np.int64(2), np.int64(10), np.int64(2)] before, using random point ['gini', np.int64(23), np.int64(4), np.int64(14)]
#   warnings.warn(
# c:\Users\llays\AppData\Local\Programs\Python\Python313\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('entropy'), np.int64(1), np.int64(10), np.int64(20)] before, using random point ['gini', np.int64(24), np.int64(5), np.int64(13)]
#   warnings.warn(
# c:\Users\llays\AppData\Local\Programs\Python\Python313\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('entropy'), np.int64(1), np.int64(10), np.int64(20)] before, using random point ['entropy', np.int64(43), np.int64(7), np.int64(18)]
#   warnings.warn(
# c:\Users\llays\AppData\Local\Programs\Python\Python313\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('gini'), np.int64(50), np.int64(10), np.int64(2)] before, using random point ['gini', np.int64(10), np.int64(4), np.int64(4)]
#   warnings.warn(
# c:\Users\llays\AppData\Local\Programs\Python\Python313\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('gini'), np.int64(50), np.int64(10), np.int64(20)] before, using random point ['gini', np.int64(19), np.int64(4), np.int64(15)]
#   warnings.warn(
# c:\Users\llays\AppData\Local\Programs\Python\Python313\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [np.str_('gini'), np.int64(50), np.int64(10), np.int64(20)] before, using random point ['gini', np.int64(24), np.int64(3), np.int64(14)]
#   warnings.warn(
# Melhores parâmetros encontrados com BayesSearchCV:
# OrderedDict({'criterion': 'gini', 'max_depth': 37, 'min_samples_leaf': 9, 'min_samples_split': 8})
# Melhor pontuação de validação cruzada: 1.00

# %%
best_model_bayes = bayes_search.best_estimator_
plot_decision_tree(best_model_bayes, feature_names, ['Tem DC', 'Não tem DC'], "Árvore de Decisão - BayesSearchCV")

# %%
previsoes_bayes = best_model_bayes.predict(X_teste_rd_under)

# %%
print(classification_report(y_teste_rd_under, previsoes_bayes))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       1.00      1.00      1.00       517
#          2.0       1.00      1.00      1.00      6779
#
#     accuracy                           1.00      7296
#    macro avg       1.00      1.00      1.00      7296
# weighted avg       1.00      1.00      1.00      7296

# %% [markdown]
# ### DSTO

# %%
#bayes_search.fit(X_treino_DSTO, y_treino_DSTO)
#print("\nMelhores parâmetros encontrados com BayesSearchCV:")
#print(bayes_search.best_params_)
#print("Melhor pontuação de validação cruzada: {:.2f}".format(bayes_search.best_score_))

# %%
#best_model_bayes = bayes_search.best_estimator_
#plot_decision_tree(best_model_bayes, feature_names, ['Tem DC', 'Não tem DC'], "Árvore de Decisão - BayesSearchCV")

# %%
#previsoes_bayes = best_model_bayes.predict(X_teste_DSTO)

# %%
#print(classification_report(y_teste_DSTO, previsoes_bayes))
