# %%
import pandas as pd
from docx import Document

# Passo 1: Definir as colunas
# Colunas numéricas
colunas_numericas = [
    'E01602', 'E017', 'E01802', 'E019', 'E025', 'F001021', 'F007021', 
    'F008021', 'VDF00102', 'J003','C008', 'M01401', 'P00901', 'P01101', 
    'P02001', 'P018', 'P02002', 'P02501', 'P02602', 'P029', 'P035', 
    'P04501', 'P04502', 'P053', 'Q064', 'H001', 'W00103', 'W00203'
]

# Colunas categóricas
colunas_categoricas = [
    'V0001', 'V0026', 'V0031', 'B001', 'C006', 'C009', 'C011', 'D001', 
    'D00301', 'D00901', 'E001', 'E002', 'E003', 'E004', 'E01201', 'F001011', 
    'F007011', 'F008011', 'VDF001', 'G060', 'I00102', 'I00401', 'I00402', 'I00403', 
    'J00101', 'J002', 'J00402', 'J00404', 'J007', 'J00801', 'J009', 'J01502', 
    'J02702', 'L033','M001', 'N004', 'N008', 'N010', 'N011', 'P02601', 
    'P027', 'P050', 'P051', 'P068', 'Q00201', 'Q03001', 'Q060', 'Q06306', 'Q06506', 
    'Q06507', 'Q06508', 'Q06509', 'Q06601', 'Q067', 'Q068', 'Q11006', 'R034', 'T001', 'H004', 'H010'
]

# Passo 2: Carregar apenas as colunas necessárias
colunas_necessarias = colunas_numericas + colunas_categoricas  # Junta as listas
df = pd.read_csv(
    r'C:\Users\llays\OneDrive\Documentos\GitHub\DoencasCardiacas\PNS2019\pns2019.csv',
    usecols=colunas_necessarias  # Carrega apenas as colunas especificadas
)

# Passo 3: Verificar se as colunas foram carregadas
print("Colunas carregadas no DataFrame:", df.columns.tolist())
# Out:
# Colunas carregadas no DataFrame: ['V0001', 'V0026', 'V0031', 'B001', 'C006', 'C008', 'C009', 'C011', 'D001', 'D00301', 'D00901', 'E001', 'E002', 'E003', 'E004', 'E01201', 'E01602', 'E017', 'E01802', 'E019', 'E025', 'F001011', 'F001021', 'F007011', 'F007021', 'F008011', 'F008021', 'VDF001', 'VDF00102', 'G060', 'I00102', 'I00401', 'I00402', 'I00403', 'J00101', 'J002', 'J003', 'J00402', 'J00404', 'J007', 'J00801', 'J009', 'J01502', 'J02702', 'L033', 'M001', 'M01401', 'N004', 'N008', 'N010', 'N011', 'P00901', 'P01101', 'P02001', 'P018', 'P02002', 'P02501', 'P02602', 'P02601', 'P027', 'P029', 'P035', 'P04501', 'P04502', 'P050', 'P051', 'P053', 'P068', 'Q00201', 'Q03001', 'Q060', 'Q06306', 'Q064', 'Q06506', 'Q06507', 'Q06508', 'Q06509', 'Q06601', 'Q067', 'Q068', 'Q11006', 'R034', 'T001', 'H001', 'H004', 'H010', 'W00103', 'W00203']

# %%
# Passo 4: Garantir que as colunas numéricas selecionadas sejam numéricas
for coluna in colunas_numericas:
    df[coluna] = pd.to_numeric(df[coluna], errors='coerce')  # Converte para numérico, forçando erros a serem NaN

# Passo 5: Criar a tabela com as estatísticas descritivas e dados faltantes para variáveis numéricas
estatisticas_numericas = {
    'Coluna': [],
    'Estatísticas': []
}

# Preenchendo a tabela de estatísticas numéricas
for coluna in colunas_numericas:
    estatisticas_numericas['Coluna'].append(coluna)
    
    # Calcular as estatísticas numéricas
    minimo = df[coluna].min()
    maximo = df[coluna].max()
    media = round(df[coluna].mean(), 2)
    desvio_padrao = round(df[coluna].std(), 2)
    faltantes = df[coluna].isnull().sum()
    total_linhas = len(df)
    porcentagem_faltantes = round((faltantes / total_linhas) * 100, 2)  # Porcentagem de dados faltantes
    
    # Concatenando as estatísticas em uma string formatada
    estatisticas_numericas['Estatísticas'].append(
        f'Mínimo: {minimo}\nMáximo: {maximo}\nMédia: {media}\nDesvio Padrão: {desvio_padrao}\nDados Faltantes: {faltantes} ({porcentagem_faltantes}%)'
    )

# Criar um DataFrame com as estatísticas numéricas
df_estatisticas_numericas = pd.DataFrame(estatisticas_numericas)

# Passo 6: Criar a tabela com as estatísticas para variáveis categóricas (total e dados faltantes)
estatisticas_categoricas = {
    'Coluna': [],
    'Estatísticas': []
}

# Preenchendo a tabela de estatísticas categóricas
for coluna in colunas_categoricas:
    estatisticas_categoricas['Coluna'].append(coluna)
    
    # Calcular o número total de valores e o número de dados faltantes
    total_valores = df[coluna].count()  # Número total de valores não nulos
    faltantes = df[coluna].isnull().sum()  # Número de dados faltantes
    porcentagem_faltantes = round((faltantes / total_linhas) * 100, 2)  # Porcentagem de dados faltantes

    # Concatenando as estatísticas em uma string formatada
    estatisticas_categoricas['Estatísticas'].append(
        f'Total de Valores: {total_valores}\nDados Faltantes: {faltantes} ({porcentagem_faltantes}%)'
    )

# %%
# Criar um DataFrame com as estatísticas categóricas
df_estatisticas_categoricas = pd.DataFrame(estatisticas_categoricas)

# Passo 7: Exibir as tabelas finais com as estatísticas
print("Análise Descritiva do Conjunto de Dados Numéricos")
print(df_estatisticas_numericas)

print("Análise Descritiva do Conjunto de Dados Categóricos")
print(df_estatisticas_categoricas)

# Passo 8: Salvar as tabelas como documentos Word (opcional)
doc = Document()
doc.add_heading('Análise Descritiva do Conjunto de Dados', 0)

# Adicionar as tabelas no documento Word

# Tabela para variáveis numéricas
doc.add_heading('Estatísticas Numéricas', level=1)
tabela_numericas = doc.add_table(rows=1, cols=len(df_estatisticas_numericas.columns))

# Adicionar cabeçalhos
hdr_cells = tabela_numericas.rows[0].cells
for i, col in enumerate(df_estatisticas_numericas.columns):
    hdr_cells[i].text = col

# Adicionar os dados das linhas
for index, row in df_estatisticas_numericas.iterrows():
    row_cells = tabela_numericas.add_row().cells
    for i, value in enumerate(row):
        row_cells[i].text = str(value)

# Tabela para variáveis categóricas
doc.add_heading('Estatísticas Categóricas', level=1)
tabela_categoricas = doc.add_table(rows=1, cols=len(df_estatisticas_categoricas.columns))

# Adicionar cabeçalhos
hdr_cells = tabela_categoricas.rows[0].cells
for i, col in enumerate(df_estatisticas_categoricas.columns):
    hdr_cells[i].text = col

# Adicionar os dados das linhas
for index, row in df_estatisticas_categoricas.iterrows():
    row_cells = tabela_categoricas.add_row().cells
    for i, value in enumerate(row):
        row_cells[i].text = str(value)

# Salvar o documento Word
doc.save('tabela_estatisticas.docx')
# Out:
# Análise Descritiva do Conjunto de Dados Numéricos
#       Coluna                                       Estatísticas
# 0     E01602  Mínimo: 4.0\nMáximo: 300000.0\nMédia: 2045.92\...
# 1       E017  Mínimo: 1.0\nMáximo: 120.0\nMédia: 37.52\nDesv...
# 2     E01802  Mínimo: 7.0\nMáximo: 50000.0\nMédia: 1876.06\n...
# 3       E019  Mínimo: 1.0\nMáximo: 88.0\nMédia: 18.38\nDesvi...
# 4       E025  Mínimo: 1.0\nMáximo: 4.0\nMédia: 2.84\nDesvio ...
# 5    F001021  Mínimo: 39.0\nMáximo: 50000.0\nMédia: 1899.0\n...
# 6    F007021  Mínimo: 10.0\nMáximo: 30000.0\nMédia: 632.27\n...
# 7    F008021  Mínimo: 1.0\nMáximo: 130000.0\nMédia: 1475.55\...
# 8   VDF00102  Mínimo: 1.0\nMáximo: 420000.0\nMédia: 583.39\n...
# 9       J003  Mínimo: 1.0\nMáximo: 14.0\nMédia: 5.92\nDesvio...
# 10      C008  Mínimo: 0.0\nMáximo: 112.0\nMédia: 35.27\nDesv...
# 11    M01401  Mínimo: 0.0\nMáximo: 3.0\nMédia: 2.47\nDesvio ...
# 12    P00901  Mínimo: 0.0\nMáximo: 7.0\nMédia: 4.4\nDesvio P...
# 13    P01101  Mínimo: 0.0\nMáximo: 7.0\nMédia: 3.31\nDesvio ...
# 14    P02001  Mínimo: 0.0\nMáximo: 7.0\nMédia: 1.2\nDesvio P...
# 15      P018  Mínimo: 0.0\nMáximo: 7.0\nMédia: 4.02\nDesvio ...
# 16    P02002  Mínimo: 0.0\nMáximo: 7.0\nMédia: 1.16\nDesvio ...
# 17    P02501  Mínimo: 0.0\nMáximo: 7.0\nMédia: 1.68\nDesvio ...
# 18    P02602  Mínimo: 0.0\nMáximo: 7.0\nMédia: 0.42\nDesvio ...
# 19      P029  Mínimo: 1.0\nMáximo: 96.0\nMédia: 4.74\nDesvio...
# 20      P035  Mínimo: 0.0\nMáximo: 7.0\nMédia: 3.37\nDesvio ...
# 21    P04501  Mínimo: 1.0\nMáximo: 6.0\nMédia: 2.89\nDesvio ...
# 22    P04502  Mínimo: 1.0\nMáximo: 6.0\nMédia: 3.77\nDesvio ...
# 23      P053  Mínimo: 2.0\nMáximo: 90.0\nMédia: 16.8\nDesvio...
# 24      Q064  Mínimo: 0.0\nMáximo: 96.0\nMédia: 48.49\nDesvi...
# 25      H001  Mínimo: 1.0\nMáximo: 5.0\nMédia: 2.94\nDesvio ...
# 26    W00103  Mínimo: 29.9\nMáximo: 138.4\nMédia: 72.25\nDes...
# 27    W00203  Mínimo: 130.0\nMáximo: 195.1\nMédia: 164.17\nD...
# Análise Descritiva do Conjunto de Dados Categóricos
#      Coluna                                       Estatísticas
# 0     V0001  Total de Valores: 293726\nDados Faltantes: 0 (...
# 1     V0026  Total de Valores: 293726\nDados Faltantes: 0 (...
# 2     V0031  Total de Valores: 293726\nDados Faltantes: 0 (...
# 3      B001  Total de Valores: 279382\nDados Faltantes: 143...
# 4      C006  Total de Valores: 279382\nDados Faltantes: 143...
# 5      C009  Total de Valores: 279382\nDados Faltantes: 143...
# 6      C011  Total de Valores: 242444\nDados Faltantes: 512...
# 7      D001  Total de Valores: 261595\nDados Faltantes: 321...
# 8    D00301  Total de Valores: 78261\nDados Faltantes: 2154...
# 9    D00901  Total de Valores: 178013\nDados Faltantes: 115...
# 10     E001  Total de Valores: 225563\nDados Faltantes: 681...
# 11     E002  Total de Valores: 113680\nDados Faltantes: 180...
# 12     E003  Total de Valores: 113335\nDados Faltantes: 180...
# 13     E004  Total de Valores: 106497\nDados Faltantes: 187...
# 14   E01201  Total de Valores: 124399\nDados Faltantes: 169...
# 15  F001011  Total de Valores: 279382\nDados Faltantes: 143...
# 16  F007011  Total de Valores: 279382\nDados Faltantes: 143...
# 17  F008011  Total de Valores: 279382\nDados Faltantes: 143...
# 18   VDF001  Total de Valores: 279382\nDados Faltantes: 143...
# 19     G060  Total de Valores: 4173\nDados Faltantes: 28955...
# 20   I00102  Total de Valores: 279382\nDados Faltantes: 143...
# 21   I00401  Total de Valores: 31627\nDados Faltantes: 2620...
# 22   I00402  Total de Valores: 31627\nDados Faltantes: 2620...
# 23   I00403  Total de Valores: 31627\nDados Faltantes: 2620...
# 24   J00101  Total de Valores: 279382\nDados Faltantes: 143...
# 25     J002  Total de Valores: 279382\nDados Faltantes: 143...
# 26   J00402  Total de Valores: 21952\nDados Faltantes: 2717...
# 27   J00404  Total de Valores: 21952\nDados Faltantes: 2717...
# 28     J007  Total de Valores: 279382\nDados Faltantes: 143...
# 29   J00801  Total de Valores: 79823\nDados Faltantes: 2139...
# 30     J009  Total de Valores: 279382\nDados Faltantes: 143...
# 31   J01502  Total de Valores: 46914\nDados Faltantes: 2468...
# 32   J02702  Total de Valores: 40357\nDados Faltantes: 2533...
# 33     L033  Total de Valores: 3683\nDados Faltantes: 29004...
# 34     M001  Total de Valores: 94111\nDados Faltantes: 1996...
# 35     N004  Total de Valores: 88953\nDados Faltantes: 2047...
# 36     N008  Total de Valores: 11457\nDados Faltantes: 2822...
# 37     N010  Total de Valores: 90846\nDados Faltantes: 2028...
# 38     N011  Total de Valores: 90846\nDados Faltantes: 2028...
# 39   P02601  Total de Valores: 90846\nDados Faltantes: 2028...
# 40     P027  Total de Valores: 90846\nDados Faltantes: 2028...
# 41     P050  Total de Valores: 90846\nDados Faltantes: 2028...
# 42     P051  Total de Valores: 1186\nDados Faltantes: 29254...
# 43     P068  Total de Valores: 90846\nDados Faltantes: 2028...
# 44   Q00201  Total de Valores: 88736\nDados Faltantes: 2049...
# 45   Q03001  Total de Valores: 84073\nDados Faltantes: 2096...
# 46     Q060  Total de Valores: 82881\nDados Faltantes: 2108...
# 47   Q06306  Total de Valores: 90846\nDados Faltantes: 2028...
# 48   Q06506  Total de Valores: 4732\nDados Faltantes: 28899...
# 49   Q06507  Total de Valores: 4732\nDados Faltantes: 28899...
# 50   Q06508  Total de Valores: 4732\nDados Faltantes: 28899...
# 51   Q06509  Total de Valores: 4732\nDados Faltantes: 28899...
# 52   Q06601  Total de Valores: 4732\nDados Faltantes: 28899...
# 53     Q067  Total de Valores: 4732\nDados Faltantes: 28899...
# 54     Q068  Total de Valores: 90846\nDados Faltantes: 2028...
# 55   Q11006  Total de Valores: 90846\nDados Faltantes: 2028...
# 56     R034  Total de Valores: 21628\nDados Faltantes: 2720...
# 57     T001  Total de Valores: 90846\nDados Faltantes: 2028...
# 58     H004  Total de Valores: 26532\nDados Faltantes: 2671...
# 59     H010  Total de Valores: 9677\nDados Faltantes: 28404...
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[3], line 48
#      45         row_cells[i].text = str(value)
#      47 # Salvar o documento Word
# ---> 48 doc.save('tabela_estatisticas.docx')
#
# File c:\Users\llays\AppData\Local\Programs\Python\Python313\Lib\site-packages\docx\document.py:149, in Document.save(self, path_or_stream)
#     143 def save(self, path_or_stream: str | IO[bytes]):
#     144     """Save this document to `path_or_stream`.
#     145
#     146     `path_or_stream` can be either a path to a filesystem location (a string) or a
#     147     file-like object.
#     148     """
# --> 149     self._part.save(path_or_stream)
#
# File c:\Users\llays\AppData\Local\Programs\Python\Python313\Lib\site-packages\docx\parts\document.py:108, in DocumentPart.save(self, path_or_stream)
#     105 def save(self, path_or_stream: str | IO[bytes]):
#     106     """Save this document to `path_or_stream`, which can be either a path to a
#     107     filesystem location (a string) or a file-like object."""
# --> 108     self.package.save(path_or_stream)
#
# File c:\Users\llays\AppData\Local\Programs\Python\Python313\Lib\site-packages\docx\opc\package.py:167, in OpcPackage.save(self, pkg_file)
#     165 for part in self.parts:
#     166     part.before_marshal()
# --> 167 PackageWriter.write(pkg_file, self.rels, self.parts)
#
# File c:\Users\llays\AppData\Local\Programs\Python\Python313\Lib\site-packages\docx\opc\pkgwriter.py:34, in PackageWriter.write(pkg_file, pkg_rels, parts)
#      30 @staticmethod
#      31 def write(pkg_file, pkg_rels, parts):
#      32     """Write a physical package (.pptx file) to `pkg_file` containing `pkg_rels` and
#      33     `parts` and a content types stream based on the content types of the parts."""
# ---> 34     phys_writer = PhysPkgWriter(pkg_file)
#      35     PackageWriter._write_content_types_stream(phys_writer, parts)
#      36     PackageWriter._write_pkg_rels(phys_writer, pkg_rels)
#
# File c:\Users\llays\AppData\Local\Programs\Python\Python313\Lib\site-packages\docx\opc\phys_pkg.py:109, in _ZipPkgWriter.__init__(self, pkg_file)
#     107 def __init__(self, pkg_file):
#     108     super(_ZipPkgWriter, self).__init__()
# --> 109     self._zipf = ZipFile(pkg_file, "w", compression=ZIP_DEFLATED)
#
# File c:\Users\llays\AppData\Local\Programs\Python\Python313\Lib\zipfile\__init__.py:1367, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1365 while True:
#    1366     try:
# -> 1367         self.fp = io.open(file, filemode)
#    1368     except OSError:
#    1369         if filemode in modeDict:
#
# PermissionError: [Errno 13] Permission denied: 'tabela_estatisticas.docx'
